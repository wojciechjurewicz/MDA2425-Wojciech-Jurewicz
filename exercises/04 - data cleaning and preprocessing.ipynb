# %%
import seaborn as sns
import pandas as pd
import numpy as np
from typing import List, Optional
from scipy import stats

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import (
    FunctionTransformer,
    LabelEncoder,
    OneHotEncoder,
    StandardScaler,
)
from sklearn.pipeline import make_pipeline

# %% [markdown]
# # Introduction
#
# We shall use X to present on how do we use python tools to process data

# %%
# Load Titanic dataset from seaborn
df = sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %% [markdown]
# # Data Cleaning
#
# Lets check the dataset for missing values

# %%
# Checking for missing values
print(df.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [markdown]
# ##  Handling Missing Values
#
# ### Dropping Missing Values
#
# We could drop a column deck since it has so many empty values. We would create a custom proper transformer to do so

# %%
class DropColumnTransformer(BaseEstimator, TransformerMixin):
    def __init__(self, columns):
        self.columns = columns

    def fit(self, X, y=None):
        return self

    def transform(self, X):
        # Drop specified columns
        X_transformed = X.drop(columns=self.columns, axis=1)
        return X_transformed

# %%
DropColumnTransformer(columns=["deck"]).fit_transform(df).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# ### Imputation Techniques (e.g., mean, median, mode)
#
# We may also use a predefined transformers in sklearn

# %%
# Create a ColumnTransformer to specify imputation for specific columns
# In this example, we specify imputation for the 'chosen_column' using SimpleImputer with strategy='mean'
# and 'other_column' without imputation


class CustomImputer(BaseEstimator, TransformerMixin):
    def __init__(self, strategy="mean", columns: Optional[List[str]] = None):
        self.strategy = strategy
        self.columns = columns if columns is not None else []
        self.imputer = SimpleImputer(strategy=self.strategy)

    def fit(self, X, y=None):
        self.imputer.fit(X[self.columns])
        return self

    def transform(self, X):
        X_transformed = X.copy()
        X_transformed[self.columns] = self.imputer.transform(X[self.columns])
        return X_transformed


CustomImputer(strategy="mean", columns=["age"]).fit_transform(df).age.value_counts()
# Out:
# age
# 29.699118    177
# 24.000000     30
# 22.000000     27
# 18.000000     26
# 28.000000     25
#             ...
# 36.500000      1
# 55.500000      1
# 0.920000       1
# 23.500000      1
# 74.000000      1
# Name: count, Length: 89, dtype: int64

# %%
df["age"].value_counts()
# Out:
# age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
#          ..
# 36.50     1
# 55.50     1
# 0.92      1
# 23.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# ## Handling Duplicates

# %%
df.duplicated().any()
# Out:
# True

# %%
df[df.duplicated()]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 47          1       3  female   NaN      0      0   7.7500        Q   Third
# 76          0       3    male   NaN      0      0   7.8958        S   Third
# 77          0       3    male   NaN      0      0   8.0500        S   Third
# 87          0       3    male   NaN      0      0   8.0500        S   Third
# 95          0       3    male   NaN      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 870         0       3    male  26.0      0      0   7.8958        S   Third
# 877         0       3    male  19.0      0      0   7.8958        S   Third
# 878         0       3    male   NaN      0      0   7.8958        S   Third
# 884         0       3    male  25.0      0      0   7.0500        S   Third
# 886         0       2    male  27.0      0      0  13.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 47   woman       False  NaN   Queenstown   yes   True
# 76     man        True  NaN  Southampton    no   True
# 77     man        True  NaN  Southampton    no   True
# 87     man        True  NaN  Southampton    no   True
# 95     man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 870    man        True  NaN  Southampton    no   True
# 877    man        True  NaN  Southampton    no   True
# 878    man        True  NaN  Southampton    no   True
# 884    man        True  NaN  Southampton    no   True
# 886    man        True  NaN  Southampton    no   True
#
# [107 rows x 15 columns]

# %% [markdown]
# ### Identifying and Removing Duplicates

# %%
drop_duplicates = FunctionTransformer(lambda X: X.drop_duplicates(), validate=False)

f"Dataset at begining {len(df)} after drop {len(drop_duplicates.fit_transform(df))}"
# Out:
# 'Dataset at begining 891 after drop 784'

# %% [markdown]
# ## Handling Outliers

# %% [markdown]
# ### Identifying Outliers

# %%
# Handling outliers


numerical_cols = df.select_dtypes(include=["int64", "float64"]).columns
z_scores = stats.zscore(df[numerical_cols])
threshold = 3
outliers = (abs(z_scores) > threshold).any(axis=1)
df[outliers]
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 13          0       3    male  39.0      1      5   31.2750        S  Third
# 16          0       3    male   2.0      4      1   29.1250        Q  Third
# 25          1       3  female  38.0      1      5   31.3875        S  Third
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 50          0       3    male   7.0      4      1   39.6875        S  Third
# ..        ...     ...     ...   ...    ...    ...       ...      ...    ...
# 846         0       3    male   NaN      8      2   69.5500        S  Third
# 850         0       3    male   4.0      4      2   31.2750        S  Third
# 858         1       3  female  24.0      0      3   19.2583        C  Third
# 863         0       3  female   NaN      8      2   69.5500        S  Third
# 885         0       3  female  39.0      0      5   29.1250        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 13     man        True  NaN  Southampton    no  False
# 16   child       False  NaN   Queenstown    no  False
# 25   woman       False  NaN  Southampton   yes  False
# 27     man        True    C  Southampton    no  False
# 50   child       False  NaN  Southampton    no  False
# ..     ...         ...  ...          ...   ...    ...
# 846    man        True  NaN  Southampton    no  False
# 850  child       False  NaN  Southampton    no  False
# 858  woman       False  NaN    Cherbourg   yes  False
# 863  woman       False  NaN  Southampton    no  False
# 885  woman       False  NaN   Queenstown    no  False
#
# [64 rows x 15 columns]

# %% [markdown]
# ## Exercise 1
#
# Create a custom transformer to detect and remove outliers. Make threshold its parameter

# %% [markdown]
# # Pipeline construction
#
# We can create a pipeline to process the data

# %%
data_cleaning = make_pipeline(
    DropColumnTransformer(columns=["deck"]),
    CustomImputer(strategy="mean", columns=["age"]),
    CustomImputer(strategy="most_frequent", columns=["embarked"]),
    FunctionTransformer(lambda X: X.drop_duplicates(), validate=False),
    # add your own outlier remover transformer step here
)

df_cleaned = data_cleaning.fit_transform(df)
df_cleaned.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %%
data_cleaning
# Out:
# Pipeline(steps=[('dropcolumntransformer',
#                  DropColumnTransformer(columns=['deck'])),
#                 ('customimputer-1', CustomImputer(columns=['age'])),
#                 ('customimputer-2',
#                  CustomImputer(columns=['embarked'], strategy='most_frequent')),
#                 ('functiontransformer',
#                  FunctionTransformer(func=<function <lambda> at 0x7f128d7449a0>))])

# %%
df_cleaned.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 780 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     780 non-null    int64
#  1   pclass       780 non-null    int64
#  2   sex          780 non-null    object
#  3   age          780 non-null    float64
#  4   sibsp        780 non-null    int64
#  5   parch        780 non-null    int64
#  6   fare         780 non-null    float64
#  7   embarked     780 non-null    object
#  8   class        780 non-null    category
#  9   who          780 non-null    object
#  10  adult_male   780 non-null    bool
#  11  embark_town  778 non-null    object
#  12  alive        780 non-null    object
#  13  alone        780 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 75.5+ KB

# %% [markdown]
# # Data Preprocessing
#
# ## Encoding Categorical Variables
#
# Most commonly we need to encode an object typed columns

# %%
df_cleaned.select_dtypes(include=["object"]).head()
# Out:
#       sex embarked    who  embark_town alive
# 0    male        S    man  Southampton    no
# 1  female        C  woman    Cherbourg   yes
# 2  female        S  woman  Southampton   yes
# 3  female        S  woman  Southampton   yes
# 4    male        S    man  Southampton    no

# %% [markdown]
# ### Label Encoding

# %%
class CustomLabelEncoder(BaseEstimator, TransformerMixin):

    def __init__(self, columns: List[str]) -> None:
        self.columns = columns
        self.encoders = {}

    def fit(self, X, y=None):
        for column in self.columns:
            self.encoders[column] = LabelEncoder()
            self.encoders[column].fit(X[column])
        return self

    def transform(self, X):
        X_transformed = X.copy()
        for column in self.columns:
            X_transformed[column] = self.encoders[column].transform(X[column])
        return X_transformed


CustomLabelEncoder(columns=["embarked", "embark_town"]).fit_transform(df_cleaned).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare  embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500         2  Third
# 1         1       1  female  38.0      1      0  71.2833         0  First
# 2         1       3  female  26.0      0      0   7.9250         2  Third
# 3         1       1  female  35.0      1      0  53.1000         2  First
# 4         0       3    male  35.0      0      0   8.0500         2  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True            2    no  False
# 1  woman       False            0   yes  False
# 2  woman       False            2   yes   True
# 3  woman       False            2   yes  False
# 4    man        True            2    no   True

# %% [markdown]
# ### One-Hot Encoding
#
# We shall use one hot for column with sex and who

# %%
from sklearn.preprocessing import OneHotEncoder


class CustomOneHotEncoder(BaseEstimator, TransformerMixin):

    def __init__(self, columns: List[str]) -> None:
        self.columns = columns
        self.encoders = {}

    def fit(self, X, y=None):
        for column in self.columns:
            self.encoders[column] = OneHotEncoder(sparse_output=False)
            self.encoders[column].fit(X[[column]])
        return self

    def transform(self, X):
        X_transformed = X.copy()
        for column in self.columns:
            encoded = pd.DataFrame(
                self.encoders[column].transform(X[[column]]),
                columns=self.encoders[column].get_feature_names_out([column]),
                index=X.index,
            )
            X_transformed = pd.concat(
                [X_transformed.drop(columns=column), encoded], axis=1
            )
        return X_transformed


CustomOneHotEncoder(columns=["sex", "who"]).fit_transform(df_cleaned)
# Out:
#      survived  pclass        age  sibsp  parch     fare embarked  class  \
# 0           0       3  22.000000      1      0   7.2500        S  Third
# 1           1       1  38.000000      1      0  71.2833        C  First
# 2           1       3  26.000000      0      0   7.9250        S  Third
# 3           1       1  35.000000      1      0  53.1000        S  First
# 4           0       3  35.000000      0      0   8.0500        S  Third
# ..        ...     ...        ...    ...    ...      ...      ...    ...
# 885         0       3  39.000000      0      5  29.1250        Q  Third
# 887         1       1  19.000000      0      0  30.0000        S  First
# 888         0       3  29.699118      1      2  23.4500        S  Third
# 889         1       1  26.000000      0      0  30.0000        C  First
# 890         0       3  32.000000      0      0   7.7500        Q  Third
#
#      adult_male  embark_town alive  alone  sex_female  sex_male  who_child  \
# 0          True  Southampton    no  False         0.0       1.0        0.0
# 1         False    Cherbourg   yes  False         1.0       0.0        0.0
# 2         False  Southampton   yes   True         1.0       0.0        0.0
# 3         False  Southampton   yes  False         1.0       0.0        0.0
# 4          True  Southampton    no   True         0.0       1.0        0.0
# ..          ...          ...   ...    ...         ...       ...        ...
# 885       False   Queenstown    no  False         1.0       0.0        0.0
# 887       False  Southampton   yes   True         1.0       0.0        0.0
# 888       False  Southampton    no  False         1.0       0.0        0.0
# 889        True    Cherbourg   yes   True         0.0       1.0        0.0
# 890        True   Queenstown    no   True         0.0       1.0        0.0
#
#      who_man  who_woman
# 0        1.0        0.0
# 1        0.0        1.0
# 2        0.0        1.0
# 3        0.0        1.0
# 4        1.0        0.0
# ..       ...        ...
# 885      0.0        1.0
# 887      0.0        1.0
# 888      0.0        1.0
# 889      1.0        0.0
# 890      1.0        0.0
#
# [780 rows x 17 columns]

# %% [markdown]
# ``

# %% [markdown]
# ### Ordinal Encoding
#
# ### Exercise 2
#
# Create your own custom Encoder that uses OrdinalEncoder instead of LabelEncoder. Allow it to pass an order as a parameter
#
# for encoder relate to
#
# ```python
# from sklearn.preprocessing import OrdinalEncoder
# ```
#
# ## Scaling Numerical Features
#
#
#
# ### Standardization

# %%
class CustomStandardScaler(BaseEstimator, TransformerMixin):

    def __init__(self, columns: List[str]) -> None:
        self.columns = columns
        self.scaler = StandardScaler()

    def fit(self, X, y=None):
        self.scaler.fit(X[self.columns])
        return self

    def transform(self, X):
        X_transformed = X.copy()
        X_transformed[self.columns] = self.scaler.transform(X[self.columns])
        return X_transformed


CustomStandardScaler(columns=["fare", "age"]).fit_transform(df_cleaned).head()
# Out:
#    survived  pclass     sex       age  sibsp  parch      fare embarked  class  \
# 0         0       3    male -0.569164      1      0 -0.528033        S  Third
# 1         1       1  female  0.598711      1      0  0.697956        C  First
# 2         1       3  female -0.277195      0      0 -0.515109        S  Third
# 3         1       1  female  0.379735      1      0  0.349817        S  First
# 4         0       3    male  0.379735      0      0 -0.512716        S  Third
#
#      who  adult_male  embark_town alive  alone
# 0    man        True  Southampton    no  False
# 1  woman       False    Cherbourg   yes  False
# 2  woman       False  Southampton   yes   True
# 3  woman       False  Southampton   yes  False
# 4    man        True  Southampton    no   True

# %% [markdown]
# ### Min-Max Scaling
#
# ### Exercise 3
#
# Create a custom transformer with min-max scalling. Check
# ```python
# from sklearn.preprocessing import MinMaxScaler
# ```
#
# ### Exercise 4
#
# Create a transformer to replace target. You may search for a thing called TargetEncoder.

# %% [markdown]
# # Preprocessing pipeline
#
# we now can create a preprocessing pipeline. It requires to provide an initial split for data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df_cleaned.drop(columns=["alone", "alive"]),
    df_cleaned["alive"],
    test_size=0.2,
    random_state=42,
)

# %%
preprocessing_pipeline = make_pipeline(
    CustomLabelEncoder(columns=["embarked", "embark_town"]),
    CustomOneHotEncoder(columns=["sex", "who"]),
    CustomStandardScaler(columns=["fare", "age"]),
    ## add your own preprocessing steps here
)

# %%
y_train
# Out:
# 789     no
# 722     no
# 141    yes
# 388     no
# 56     yes
#       ...
# 72      no
# 112     no
# 287     no
# 483    yes
# 108     no
# Name: alive, Length: 624, dtype: object

# %%
preprocessing_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('customlabelencoder',
#                  CustomLabelEncoder(columns=['embarked', 'embark_town'])),
#                 ('customonehotencoder',
#                  CustomOneHotEncoder(columns=['sex', 'who'])),
#                 ('customstandardscaler',
#                  CustomStandardScaler(columns=['fare', 'age']))])

# %%
results = preprocessing_pipeline.transform(X_test)
results
# Out:
#      survived  pclass       age  sibsp  parch      fare  embarked   class  \
# 676         0       3 -0.405579      0      0 -0.508814         2   Third
# 667         0       3 -0.031987      0      0 -0.514001         2   Third
# 611         0       3 -0.031987      0      0 -0.527675         2   Third
# 728         0       2 -0.369651      1      0 -0.170247         2  Second
# 545         0       1  2.432768      0      0 -0.170247         2   First
# ..        ...     ...       ...    ...    ...       ...       ...     ...
# 382         0       3  0.133348      0      0 -0.511172         2   Third
# 82          1       3 -0.031987      0      0 -0.513765         1   Third
# 156         1       3 -1.016363      0      0 -0.514787         1   Third
# 362         0       3  1.067487      0      1 -0.388020         0   Third
# 177         0       1  1.426771      0      0 -0.119085         0   First
#
#      adult_male  embark_town  sex_female  sex_male  who_child  who_man  \
# 676        True            2         0.0       1.0        0.0      1.0
# 667        True            2         0.0       1.0        0.0      1.0
# 611        True            2         0.0       1.0        0.0      1.0
# 728        True            2         0.0       1.0        0.0      1.0
# 545        True            2         0.0       1.0        0.0      1.0
# ..          ...          ...         ...       ...        ...      ...
# 382        True            2         0.0       1.0        0.0      1.0
# 82        False            1         1.0       0.0        0.0      0.0
# 156       False            1         1.0       0.0        0.0      0.0
# 362       False            0         1.0       0.0        0.0      0.0
# 177       False            0         1.0       0.0        0.0      0.0
#
#      who_woman
# 676        0.0
# 667        0.0
# 611        0.0
# 728        0.0
# 545        0.0
# ..         ...
# 382        0.0
# 82         1.0
# 156        1.0
# 362        1.0
# 177        1.0
#
# [156 rows x 15 columns]

# %%
y_test
# Out:
# 676     no
# 667     no
# 611     no
# 728     no
# 545     no
#       ...
# 382     no
# 82     yes
# 156    yes
# 362     no
# 177     no
# Name: alive, Length: 156, dtype: object

# %% [markdown]
# # Pass-Fail Exercise
#
# Complete the exercises presented in this notebook. Then copy this notebook to your student directory and create a Merge request with it. Please do not commit thios file.
